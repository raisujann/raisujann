# %%
import numpy as np
print(np.__version__)
# Out:
# 2.2.2

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import matplotlib as plt
print(plt.__version__)
# Out:
# 3.10.1

# %%
import pandas as pd
mydf = pd.read_csv('machine-readable-business-employment-data-sep-2024-quarter.csv')
mydf.head(3)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 2    Filled jobs  Agriculture, Forestry and Fishing         Actual
#
#    Series_title_4  Series_title_5
# 0             NaN             NaN
# 1             NaN             NaN
# ...

# %%
mydf.tail(1)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 23736    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 23736          0  Business Data Collection - BDC
#
#                                               Group  \
# 23736  Territorial authority by employment variable
#
#                                Series_title_1  \
# 23736  Filled jobs (workplace location based)
#
#                            Series_title_2 Series_title_3  Series_title_4  \
# 23736  Area Outside Territorial Authority         Actual             NaN
#
#        Series_title_5
# 23736             NaN

# %%
mydf.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
mydf
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 23732    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 23733    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 23734    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 23735    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 23736    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
mydf.shape
# Out:
# (23737, 14)

# %%
mydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23737 entries, 0 to 23736
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  23737 non-null  object
#  1   Period            23737 non-null  float64
#  2   Data_value        20898 non-null  float64
#  3   Suppressed        2839 non-null   object
#  4   STATUS            23737 non-null  object
#  5   UNITS             23737 non-null  object
#  6   Magnitude         23737 non-null  int64
#  7   Subject           23737 non-null  object
#  8   Group             23737 non-null  object
#  9   Series_title_1    23737 non-null  object
#  10  Series_title_2    23737 non-null  object
#  11  Series_title_3    23737 non-null  object
#  12  Series_title_4    0 non-null      float64
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.5+ MB

# %%
pd.set_option('display.max_columns' , 14)
pd.set_option('display.max_rows' , 100)

# %%
schema_mydf=pd.read_csv('machine-readable-business-employment-data-sep-2024-quarter.csv')

# %%
schema_mydf
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 23732    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 23733    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 23734    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 23735    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 23736    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
import pandas as pd
mydf= pd.read_csv('machine-readable-business-employment-data-sep-2024-quarter.csv')
mydf
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 23732    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 23733    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 23734    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 23735    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 23736    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
mydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23737 entries, 0 to 23736
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  23737 non-null  object
#  1   Period            23737 non-null  float64
#  2   Data_value        20898 non-null  float64
#  3   Suppressed        2839 non-null   object
#  4   STATUS            23737 non-null  object
#  5   UNITS             23737 non-null  object
#  6   Magnitude         23737 non-null  int64
#  7   Subject           23737 non-null  object
#  8   Group             23737 non-null  object
#  9   Series_title_1    23737 non-null  object
#  10  Series_title_2    23737 non-null  object
#  11  Series_title_3    23737 non-null  object
#  12  Series_title_4    0 non-null      float64
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.5+ MB

# %%
mydf=pd.read_csv('machine-readable-business-employment-data-sep-2024-quarter.csv', usecols=['Period', 'UNITS'])
print(mydf)
# Out:
#         Period   UNITS
# 0      2011.06  Number
# 1      2011.09  Number
# 2      2011.12  Number
# 3      2012.03  Number
# 4      2012.06  Number
# ...        ...     ...
# 23732  2017.06  Number
# 23733  2017.09  Number
# 23734  2017.12  Number
# 23735  2018.03  Number
# 23736  2018.06  Number
#
# [23737 rows x 2 columns]

# %%
mydf=pd.read_csv('machine-readable-business-employment-data-sep-2024-quarter.csv', index_col='Subject')
print(mydf)
# Out:
#                                Series_reference   Period  Data_value  \
# Subject
# Business Data Collection - BDC      BDCQ.SEA1AA  2011.06     80078.0
# Business Data Collection - BDC      BDCQ.SEA1AA  2011.09     78324.0
# Business Data Collection - BDC      BDCQ.SEA1AA  2011.12     85850.0
# Business Data Collection - BDC      BDCQ.SEA1AA  2012.03     90743.0
# Business Data Collection - BDC      BDCQ.SEA1AA  2012.06     81780.0
# ...                                         ...      ...         ...
# Business Data Collection - BDC    BDCQ.SEE3999A  2017.06         NaN
# Business Data Collection - BDC    BDCQ.SEE3999A  2017.09         NaN
# Business Data Collection - BDC    BDCQ.SEE3999A  2017.12         NaN
# Business Data Collection - BDC    BDCQ.SEE3999A  2018.03         NaN
# Business Data Collection - BDC    BDCQ.SEE3999A  2018.06         NaN
#
#                                Suppressed STATUS   UNITS  Magnitude  \
# Subject
# ...
